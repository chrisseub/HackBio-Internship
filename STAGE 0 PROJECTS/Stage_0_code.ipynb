# %% [markdown]
# <a href="https://colab.research.google.com/github/chrisseub/HackBio-Internship/blob/main/Stage_0_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Simple Team Tyrosine Info Collector
print("Team Tyrosine")

name = input("Enter your name: ")
slack_username = input("Enter your slack username: ")
country = input("Enter your country: ")
hobby = input("Enter your hobby: ")
affiliations = input("Enter your affiliations: ")
gene = input("Enter your favorite gene: ")
dna = input("Enter the DNA sequence: ")

print("\n Team Member Info ")
print(f"Name: {name}")
print(f"Slack: {slack_username}")
print(f"Country: {country}")
print(f"Hobby: {hobby}")
print(f"Affiliations: {affiliations}")
print(f"Favorite Gene: {gene}")
print(f"DNA Sequence: {dna}")
# Out:
# Team Tyrosine
# Enter your name: Christopher
# Enter your slack username: Chrisseun
# Enter your country: Nigeria
# Enter your hobby: Eating
# Enter your affiliations: OAU
# Enter your favorite gene: Tab
# Enter the DNA sequence: GATA
#
#  Team Member Info
# Name: Christopher
# Slack: Chrisseun
# Country: Nigeria
# Hobby: Eating
# Affiliations: OAU
# Favorite Gene: Tab
# DNA Sequence: GATA
